# %% [markdown]
# # Why Seaborn Library?

# %% [markdown]
# It is a wrapper over matplotlib to provide high level visualization api.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# # Distribution Plot

# %%
# DEPRECATED
sns.displot(crash_df['alcohol'],kde=True, bins=10 );

# %%
sns.jointplot(x='speeding',y='alcohol', data=crash_df, kind='reg');

# %%
sns.jointplot(x='speeding',y='alcohol', data=crash_df, kind='kde');

# %%
sns.jointplot(x='speeding',y='alcohol', data=crash_df, kind='hex');

# %% [markdown]
# # KDE Plot

# %%
sns.kdeplot(crash_df['alcohol']);

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(crash_df);

# %%
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Using hue for categorical data
sns.pairplot(tips_df, hue='sex');

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(tips_df['tip']);

# %% [markdown]
# # Styling

# %%
# Not working in Pycharm
sns.set_style('ticks')
plt.figure(figsize=(20,5))
sns.jointplot(x='speeding', y='alcohol', data=crash_df,kind ='reg')

# %% [markdown]
# # Categorical Plot

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df);

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='sex', data=tips_df);

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex');

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex', plit=True);

# %% [markdown]
# # Strip Plot

# %%
sns.stripplot(x='day', y='total_bill', data=tips_df);

# %%
sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True);

# %%
sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue = 'sex');

# %%
sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue = 'sex', dodge=True);

# %% [markdown]
# # Swarm Plot

# %%
sns.violinplot(x='day', y = 'total_bill', data=tips_df);
sns.swarmplot(x='day', y = 'total_bill', data=tips_df, color='white')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y = 'total_bill', data=tips_df);

# %% [markdown]
# # Palettes

# %%
# Palette = Coloring options
# check matplotlib coloring options for palettes colors options
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette='magma');
plt.legend(loc=0);

# %% [markdown]
# # Matrix Plot

# %% [markdown]
# ## Heatmaps

# %%
crash_mat = crash_df.corr()
sns.heatmap(crash_mat, annot=True, cmap='Greens');

# %%
flights = sns.load_dataset('flights')
# Create Pivot Table
flights.pivot_table(index='month', columns='year', values='passengers')
sns.heatmap(flights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [107], in <cell line: 4>()
#       2 # Create Pivot Table
#       3 flights.pivot_table(index='month', columns='year', values='passengers')
# ----> 4 sns.heatmap(flights)
#
# File ~/.local/share/virtualenvs/openDS-MZRDdKgs/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %% [markdown]
# ## Cluster Map

# %%
iris = sns.load_dataset('iris')
species = iris.pop('species')
# Hierarchical Clustered Heatmap
sns.clustermap(iris);
# Standardize data to focus on hierarchical proximity

# %%
sns.clustermap(flights, standard_scale=1)
# Out:
# /Users/ahsan/.local/share/virtualenvs/openDS-MZRDdKgs/lib/python3.8/site-packages/seaborn/matrix.py:981: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   subtract = standardized.min()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 sns.clustermap(flights, standard_scale=1)
#
# File ~/.local/share/virtualenvs/openDS-MZRDdKgs/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
# ...

# %% [markdown]
# ## Pair Grid

# %%
# Configuring pairplot or Pairplot with more control
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map(plt.scatter);
iris_g.map_diag(plt.hist);

# %%
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map_diag(plt.hist);
iris_g.map_offdiag(plt.scatter);

# %%
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map_diag(plt.hist);
iris_g.map_upper(plt.scatter);
iris_g.map_lower(sns.kdeplot);

# %% [markdown]
# # Facade Grid

# %%
#BÙGGY
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker')
tips_fg.map(plt.scatter, 'total_bill',bins=8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
# ----> 1 tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker')
#       2 tips_fg.map(plt.scatter, 'total_bill',bins=8)
#
# File ~/.local/share/virtualenvs/openDS-MZRDdKgs/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %% [markdown]
# # Regression Plot

# %%
sns.lmplot(x="total_bill", y="tip",col='sex', hue='sex', data=tips_df, markers=['o', '×'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [142], in <cell line: 1>()
# ----> 1 sns.lmplot(x="total_bill", y="tip",col='sex', hue='sex', data=tips_df, markers=['o', '×'])
#
# File ~/.local/share/virtualenvs/openDS-MZRDdKgs/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
# Reference= https://www.youtube.com/watch?v=6GUZXDef2U0
